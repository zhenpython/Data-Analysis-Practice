# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Import Data original
og_1 = pd.read_csv("/content/drive/MyDrive/datasets/index_1.csv")
#Import data penjualan kedua
og_2 = pd.read_csv("/content/drive/MyDrive/datasets/index_2.csv")

# %%
#Membuat copy data penjualan pertama
df_1 = pd.read_csv("/content/drive/MyDrive/datasets/index_1.csv")
#Membuat copy data penjualan kedua
df_2 = pd.read_csv("/content/drive/MyDrive/datasets/index_2.csv")

# %%
df_1.head(10)
# Out:
#          date                 datetime cash_type                 card  money  \
# 0  2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001   38.7
# 1  2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002   38.7
# 2  2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002   38.7
# 3  2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003   28.9
# 4  2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004   38.7
# 5  2024-03-01  2024-03-01 15:39:47.726      card  ANON-0000-0000-0005   33.8
# 6  2024-03-01  2024-03-01 16:19:02.756      card  ANON-0000-0000-0006   38.7
# 7  2024-03-01  2024-03-01 18:39:03.580      card  ANON-0000-0000-0007   33.8
# 8  2024-03-01  2024-03-01 19:22:01.762      card  ANON-0000-0000-0008   38.7
# 9  2024-03-01  2024-03-01 19:23:15.887      card  ANON-0000-0000-0008   33.8
#
#            coffee_name
# 0                Latte
# 1        Hot Chocolate
# 2        Hot Chocolate
# 3            Americano
# 4                Latte
# 5  Americano with Milk
# 6        Hot Chocolate
# 7  Americano with Milk
# 8                Cocoa
# 9  Americano with Milk

# %%
df_2.head()
# Out:
#          date             datetime cash_type  money            coffee_name
# 0  2025-02-08  2025-02-08 14:26:04      cash   15.0                    Tea
# 1  2025-02-08  2025-02-08 14:28:26      cash   15.0                    Tea
# 2  2025-02-08  2025-02-08 14:33:04      card   20.0               Espresso
# 3  2025-02-08  2025-02-08 15:51:04      card   30.0  Chocolate with coffee
# 4  2025-02-08  2025-02-08 16:35:01      cash   27.0    Chocolate with milk

# %%
#Delete column card as it is not needed and not in the 2nd dataset
df_1.drop(["date", "card"], axis=1, inplace=True)

# %%
df_2.drop("date", axis=1, inplace=True)

# %%
#Cek informasi
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3636 entries, 0 to 3635
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   datetime     3636 non-null   object
#  1   cash_type    3636 non-null   object
#  2   money        3636 non-null   float64
#  3   coffee_name  3636 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 113.8+ KB

# %%
#Cek informasi
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   datetime     262 non-null    object
#  1   cash_type    262 non-null    object
#  2   money        262 non-null    float64
#  3   coffee_name  262 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 8.3+ KB

# %%
df_1.isnull().sum().sort_values(ascending=False)
# Out:
# datetime       0
# cash_type      0
# money          0
# coffee_name    0
# dtype: int64

# %%
df_2.isnull().sum().sort_values(ascending=False)
# Out:
# datetime       0
# cash_type      0
# money          0
# coffee_name    0
# dtype: int64

# %%
df_1.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_2.duplicated().sum()
# Out:
# np.int64(2)

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3636 entries, 0 to 3635
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   datetime     3636 non-null   object
#  1   cash_type    3636 non-null   object
#  2   money        3636 non-null   float64
#  3   coffee_name  3636 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 113.8+ KB

# %%
df_2.drop_duplicates(inplace=True)

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 260 entries, 0 to 261
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   datetime     260 non-null    object
#  1   cash_type    260 non-null    object
#  2   money        260 non-null    float64
#  3   coffee_name  260 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 10.2+ KB

# %%
#Merge data pertama dan kedua
full_df = pd.concat([df_1, df_2], ignore_index=True)

# %%
full_df
# Out:
#                      datetime cash_type  money                 coffee_name
# 0     2024-03-01 10:15:50.520      card   38.7                       Latte
# 1     2024-03-01 12:19:22.539      card   38.7               Hot Chocolate
# 2     2024-03-01 12:20:18.089      card   38.7               Hot Chocolate
# 3     2024-03-01 13:46:33.006      card   28.9                   Americano
# 4     2024-03-01 13:48:14.626      card   38.7                       Latte
# ...                       ...       ...    ...                         ...
# 3891      2025-03-23 14:55:46      cash   30.0                  Cappuccino
# 3892      2025-03-23 15:15:36      card   25.0               Irish whiskey
# 3893      2025-03-23 17:59:25      card   28.0             Super chocolate
# 3894      2025-03-23 18:01:33      card   28.0  Vanilla with Irish whiskey
# 3895      2025-03-23 21:23:11      card   29.0   Coffee with Irish whiskey
#
# [3896 rows x 4 columns]

# %%
#Konversi date time menjadi format date and time
full_df["datetime_converted"] = pd.to_datetime(full_df["datetime"], format="mixed")

#Ekstrak jam pada datetime
full_df["hour"] = full_df["datetime_converted"].dt.hour

#Kolom datetime hanya tanggal, bulan dan tahun saja
full_df["datetime_converted"] = full_df["datetime_converted"].dt.strftime("%Y-%m-%d")

# %%
full_df.drop("datetime", axis=1, inplace=True)

# %%
full_df.head()
# Out:
#   cash_type  money    coffee_name datetime_converted  hour
# 0      card   38.7          Latte         2024-03-01    10
# 1      card   38.7  Hot Chocolate         2024-03-01    12
# 2      card   38.7  Hot Chocolate         2024-03-01    12
# 3      card   28.9      Americano         2024-03-01    13
# 4      card   38.7          Latte         2024-03-01    13

# %% [markdown]
# ## Explore data analytics

# %%
# Statistics deskriptif
full_df.describe()
# Out:
#              money         hour
# count  3896.000000  3896.000000
# mean     31.383876    14.206622
# std       5.063845     4.214976
# min      15.000000     6.000000
# 25%      27.920000    11.000000
# 50%      32.820000    14.000000
# 75%      35.760000    18.000000
# max      40.000000    23.000000

# %%
full_df.hist()
# Out:
# array([[<Axes: title={'center': 'money'}>,
#         <Axes: title={'center': 'hour'}>]], dtype=object)

# %%
sns.boxplot(data=full_df)
# Out:
# <Axes: >

# %%
full_df['cash_type'].unique()
# Out:
# array(['card', 'cash'], dtype=object)

# %%
sns.countplot(x="cash_type", data=full_df)
# Out:
# <Axes: xlabel='cash_type', ylabel='count'>

# %%
sns.histplot(x="hour", data=full_df)
# Out:
# <Axes: xlabel='hour', ylabel='Count'>

# %%
#Analisis dari bulan
full_df['datetime_converted'] = pd.to_datetime(full_df['datetime_converted'])
full_df['month'] = full_df['datetime_converted'].dt.month

# %%
sns.countplot(x="month", data=full_df)
# Out:
# <Axes: xlabel='month', ylabel='count'>

# %%
# Melihat rata rata penjualan per hari
monthly_sales = full_df.groupby('datetime_converted')['money'].mean()
monthly_sales
# Out:
# datetime_converted
# 2024-03-01    36.027273
# 2024-03-02    32.585714
# 2024-03-03    34.910000
# 2024-03-04    33.800000
# 2024-03-05    37.611111
#                 ...
# 2025-03-19    29.367692
# 2025-03-20    29.808696
# 2025-03-21    30.908333
# 2025-03-22    27.882727
# 2025-03-23    30.366154
# Name: money, Length: 381, dtype: float64

# %%
monthly_sales = full_df.groupby('month')['money'].mean().reset_index()

# %%
plt.figure(figsize=(10, 6))
plt.plot(monthly_sales['month'], monthly_sales['money'], marker='o', linestyle ='-')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Monthly Average Sales')
# Out:
# Text(0.5, 1.0, 'Monthly Average Sales')

# %%
# Melihat rata rata penjualan per bulan setiap tahun
monthly_sales = full_df.groupby(['datetime_converted', 'month'])['money'].mean()
plt.plot
# Out:
# datetime_converted  month
# 2024-03-01          3        36.027273
# 2024-03-02          3        32.585714
# 2024-03-03          3        34.910000
# 2024-03-04          3        33.800000
# 2024-03-05          3        37.611111
#                                ...
# 2025-03-19          3        29.367692
# 2025-03-20          3        29.808696
# 2025-03-21          3        30.908333
# 2025-03-22          3        27.882727
# 2025-03-23          3        30.366154
# Name: money, Length: 381, dtype: float64

# %%
top_5 = full_df['coffee_name'].value_counts().reset_index().head(5)
top_5
# Out:
#            coffee_name  count
# 0  Americano with Milk    824
# 1                Latte    806
# 2            Americano    593
# 3           Cappuccino    517
# 4              Cortado    292

# %%
sns.barplot(x = 'coffee_name', y ='count', data=top_5)
plt.title('Top 5 Coffee')
plt.xlabel('Coffee Name')
plt.ylabel('Count')
plt.show()

# %%
plt.figure

# %%
sns.countplot(y ="coffee_name", data = full_df)
plt.xticks(rotation = 90)
plt.show()

# %%
top_5['coffee_name'].unique()
# Out:
# array(['Americano with Milk', 'Latte', 'Americano', 'Cappuccino',
#        'Cortado'], dtype=object)

# %%
top_5_menu_hour = full_df[['hour', 'coffee_name']]
# Filter the data using top 5 menu unique category
top_5_menu_hour = top_5_menu_hour[top_5_menu_hour['coffee_name'].isin(top_5['coffee_name'].unique())]

# %%
sns.histplot(x="hour", hue='coffee_name', data=top_5_menu_hour)
# Out:
# <Axes: xlabel='hour', ylabel='Count'>

# %%
filtered_hour
